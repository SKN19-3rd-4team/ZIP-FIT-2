# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from database import Initializing

db_init = Initializing()

# %%
# 초기화
db_init.set_default_tables(drop=True)
# Out:
# 👎 table LH 공고 크롤링 배치-[ANNC_LH_TEMP] dropped (CASCADE)
# ✅ table LH 공고 크롤링 배치-[ANNC_LH_TEMP] created
# 👎 table 공고 전체 테이블-[ANNC_ALL] dropped (CASCADE)
# ✅ table 공고 전체 테이블-[ANNC_ALL] created
# 👎 table 공고 파일-[ANNC_FILES] dropped (CASCADE)
# ✅ table 공고 파일-[ANNC_FILES] created
# 👎 table 공고 파일 청크 벡터-[DOC_CHUNKS] dropped (CASCADE)
# ✅ table 공고 파일 청크 벡터-[DOC_CHUNKS] created
